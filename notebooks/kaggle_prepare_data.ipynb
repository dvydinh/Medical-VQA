# %% [markdown]
# # Prepare Mixed Medical VQA Dataset (VQA-RAD + SLAKE)
#
# This notebook downloads VQA-RAD and SLAKE datasets, filters for English questions, and merges them into a single dataset for training. All SLAKE samples are assigned to the `train` split so that the `test` split remains strictly VQA-RAD for accurate benchmarking.

# %%
# !pip install -q datasets Pillow

# %%
import os
import shutil

WORK_DIR = "/kaggle/working/Medical-VQA"
if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)

os.system(f"git clone https://github.com/dvydinh/Medical-VQA.git {WORK_DIR}")
os.chdir(WORK_DIR)
print("Repository cloned.")

# %%
# !python scripts/prepare_mixed_data.py

# %% [markdown]
# ## ✅ Xong!
# Bây giờ hãy ấn **Save Version** (chọn **Save & Run All**) để Kaggle lưu lại toàn bộ dữ liệu này.
# Sau đó, bạn có thể sử dụng Output của Notebook này làm Dataset Input cho Notebook Training (V9).
